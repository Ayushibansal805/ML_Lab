# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushibansal805/ML_Lab/blob/main/lab_ml3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/glass.data", names=['Id', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Id      214 non-null    int64
#  1   RI      214 non-null    float64
#  2   Na      214 non-null    float64
#  3   Mg      214 non-null    float64
#  4   Al      214 non-null    float64
#  5   Si      214 non-null    float64
#  6   K       214 non-null    float64
#  7   Ca      214 non-null    float64
#  8   Ba      214 non-null    float64
#  9   Fe      214 non-null    float64
#  10  Type    214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
data.describe()
# Out:
#                Id          RI          Na          Mg          Al          Si  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean   107.500000    1.518365   13.407850    2.684533    1.444907   72.650935
# std     61.920648    0.003037    0.816604    1.442408    0.499270    0.774546
# min      1.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     54.250000    1.516522   12.907500    2.115000    1.190000   72.280000
# 50%    107.500000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    160.750000    1.519157   13.825000    3.600000    1.630000   73.087500
# max    214.000000    1.533930   17.380000    4.490000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     0.497056    8.956963    0.175047    0.057009    2.780374
# std      0.652192    1.423153    0.497219    0.097439    2.103739
# ...

# %%
data.head()
# Out:
#    Id       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0   1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
data.tail()
# Out:
#       Id       RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  210  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  211  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  212  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  213  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  214  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
data.columns
# Out:
# Index(['Id', 'RI', 'Na', 'Mg', 'Al', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type'], dtype='object')

# %%
data.shape
# Out:
# (214, 11)

# %%
# what is the relation between elements
data.corr()
# Out:
#             Id        RI        Na        Mg        Al        Si         K  \
# Id    1.000000 -0.072209  0.375722 -0.650328  0.490113  0.061232  0.003149
# RI   -0.072209  1.000000 -0.191885 -0.122274 -0.407326 -0.542052 -0.289833
# Na    0.375722 -0.191885  1.000000 -0.273732  0.156794 -0.069809 -0.266087
# Mg   -0.650328 -0.122274 -0.273732  1.000000 -0.481799 -0.165927  0.005396
# Al    0.490113 -0.407326  0.156794 -0.481799  1.000000 -0.005524  0.325958
# Si    0.061232 -0.542052 -0.069809 -0.165927 -0.005524  1.000000 -0.193331
# K     0.003149 -0.289833 -0.266087  0.005396  0.325958 -0.193331  1.000000
# Ca    0.090800  0.810403 -0.275442 -0.443750 -0.259592 -0.208732 -0.317836
# Ba    0.451001 -0.000386  0.326603 -0.492262  0.479404 -0.102151 -0.042618
# Fe   -0.072794  0.143010 -0.241346  0.083060 -0.074402 -0.094201 -0.007719
# Type  0.877357 -0.164237  0.502898 -0.744993  0.598829  0.151565 -0.010054
#
#             Ca        Ba        Fe      Type
# ...

# %%
import seaborn as sns
sns.kdeplot(data['Id'])
# Out:
# <Axes: xlabel='Id', ylabel='Density'>

# %%
sns.kdeplot(data['Al'])
# Out:
# <Axes: xlabel='Al', ylabel='Density'>

# %%
sns.kdeplot(data['Ba'])
# Out:
# <Axes: xlabel='Ba', ylabel='Density'>

# %%
sns.kdeplot(data['Ca'])
# Out:
# <Axes: xlabel='Ca', ylabel='Density'>

# %%
sns.kdeplot(data['Fe'])
# Out:
# <Axes: xlabel='Fe', ylabel='Density'>

# %%
sns.kdeplot(data['K'])
# Out:
# <Axes: xlabel='K', ylabel='Density'>

# %%
sns.kdeplot(data['Mg'])
# Out:
# <Axes: xlabel='Mg', ylabel='Density'>

# %%
sns.kdeplot(data['Na'])
# Out:
# <Axes: xlabel='Na', ylabel='Density'>

# %%
sns.kdeplot(data['RI'])
# Out:
# <Axes: xlabel='RI', ylabel='Density'>

# %%
sns.kdeplot(data['Si'])
# Out:
# <Axes: xlabel='Si', ylabel='Density'>

# %%
sns.kdeplot(data['Type'])
# Out:
# <Axes: xlabel='Type', ylabel='Density'>

# %%
sns.scatterplot(data['Al'])
# Out:
# <Axes: ylabel='Al'>

# %%
sns.scatterplot(data['Ba'])
# Out:
# <Axes: ylabel='Ba'>

# %%
sns.scatterplot(data['Ca'])
# Out:
# <Axes: ylabel='Ca'>

# %%
sns.scatterplot(data['Fe'])
# Out:
# <Axes: ylabel='Fe'>

# %%
sns.scatterplot(data['K'])
# Out:
# <Axes: ylabel='K'>

# %%
sns.scatterplot(data['Mg'])
# Out:
# <Axes: ylabel='Mg'>

# %%
sns.scatterplot(data['Na'])
# Out:
# <Axes: ylabel='Na'>

# %%
sns.scatterplot(data['RI'])
# Out:
# <Axes: ylabel='RI'>

# %%
sns.scatterplot(data['Si'])
# Out:
# <Axes: ylabel='Si'>

# %%
sns.pairplot(data=data)

# %%
sns.violinplot(data['Al'])
# Out:
# <Axes: ylabel='Al'>

# %%
sns.violinplot(data['Ba'])
# Out:
# <Axes: ylabel='Ba'>

# %%
sns.violinplot(data['Ca'])
# Out:
# <Axes: ylabel='Ca'>

# %%
sns.violinplot(data['Fe'])
# Out:
# <Axes: ylabel='Fe'>

# %%
sns.violinplot(data['K'])
# Out:
# <Axes: ylabel='K'>

# %%
sns.violinplot(data['Mg'])
# Out:
# <Axes: ylabel='Mg'>

# %%
sns.violinplot(data['Na'])
# Out:
# <Axes: ylabel='Na'>

# %%
sns.violinplot(data['RI'])
# Out:
# <Axes: ylabel='RI'>

# %%
sns.violinplot(data['Si'])
# Out:
# <Axes: ylabel='Si'>

# %%
sns.boxplot(data['Al'])
# Out:
# <Axes: ylabel='Al'>

# %%
sns.boxplot(data['Ba'])
# Out:
# <Axes: ylabel='Ba'>

# %%
sns.boxplot(data['Ca'])
# Out:
# <Axes: ylabel='Ca'>

# %%
sns.boxplot(data['Fe'])
# Out:
# <Axes: ylabel='Fe'>

# %%
sns.boxplot(data['K'])
# Out:
# <Axes: ylabel='K'>

# %%
sns.boxplot(data['Mg'])
# Out:
# <Axes: ylabel='Mg'>

# %%
sns.boxplot(data['Na'])
# Out:
# <Axes: ylabel='Na'>

# %%
sns.boxplot(data['RI'])
# Out:
# <Axes: ylabel='RI'>

# %%
sns.boxplot(data['Si'])
# Out:
# <Axes: ylabel='Si'>

# %%
# why do we need to boost the ri of glass

# %%
data.drop('Id', axis=1, inplace=True)

# %%
data
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
y = data['Type']
data.drop('Type', axis=1, inplace=True)
x = data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=42)

# %%
x_train.head()
# Out:
#           RI     Na    Mg    Al     Si     K     Ca    Ba    Fe
# 79   1.51590  12.82  3.52  1.90  72.86  0.69   7.97  0.00  0.00
# 161  1.51934  13.64  3.54  0.75  72.65  0.16   8.89  0.15  0.24
# 109  1.51818  13.72  0.00  0.56  74.45  0.00  10.99  0.00  0.00
# 127  1.52081  13.78  2.28  1.43  71.99  0.49   9.85  0.00  0.17
# 95   1.51860  13.36  3.43  1.43  72.26  0.51   8.60  0.00  0.00

# %%
y_train.head()
# Out:
# 79     2
# 161    3
# 109    2
# 127    2
# 95     2
# Name: Type, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import f1_score, confusion_matrix
print(f1_score(y_pred, y_test, average='weighted'))
# Out:
# 0.7530276944597629

# %%
from sklearn.ensemble import RandomForestClassifier
model1 = RandomForestClassifier()

# %%
model1.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred1 = model1.predict(x_test)

# %%
print(f1_score(y_pred1, y_test, average='weighted'))
# Out:
# 0.8841298236647074

# %%
from sklearn.tree import ExtraTreeClassifier
model2 = ExtraTreeClassifier()

# %%
model2.fit(x_train, y_train)
# Out:
# ExtraTreeClassifier()

# %%
y_pred2 = model2.predict(x_test)

# %%
print(f1_score(y_pred, y_test, average='weighted'))
# Out:
# 0.7530276944597629

# %%
from xgboost import XGBClassifier
model3 = XGBClassifier()

# %%
model3.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-28992808.py in <cell line: 0>()
# ----> 1 model3.fit(x_train, y_train)
#
# /usr/local/lib/python3.12/dist-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     772             for k, arg in zip(sig.parameters, args):
#     773                 kwargs[k] = arg
# --> 774             return func(**kwargs)
#     775
#     776         return inner_f
#
# /usr/local/lib/python3.12/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1761                 or not (classes == expected_classes).all()
#    1762             ):
# -> 1763                 raise ValueError(
#    1764                     f"Invalid classes inferred from unique values of `y`.  "
# ...
